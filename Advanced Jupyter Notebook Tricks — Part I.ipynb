# %% [markdown]
# # How to run a bash session

# %%
# %%bash
# for i in a b c;
# do
# echo $i
# done
# Out:
# a
# b
# c

# %%
% time
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.72 µs

# %%
# %%latex
# \begin{align}
# a = \frac{1}{2} && b = \frac{1}{3} && c = \frac{1}{4} \\
# a && b && c \\
# 1 && 2 && 3
# \end{align}
# Out:
# \begin{align}
# a = \frac{1}{2} && b = \frac{1}{3} && c = \frac{1}{4} \\
# a && b && c \\
# 1 && 2 && 3
# \end{align}

# %%
# %time x = range(10000)
# Out:
# CPU times: user 6 µs, sys: 6 µs, total: 12 µs
# Wall time: 8.11 µs

# %%
# %%timeit x = range(10000)
max(x)
# Out:
# 243 µs ± 6.56 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# X <- runif(10)
# Y <- runif(10)

# %%
# %R plot(X, Y)

# %%
import numpy as np
X = np.array([4.5, 6.3, 7.9])
X.mean()
# Out:
# 6.2333333333333343

# %%
# %Rpush X
# %R mean(X)
# Out:
# array([ 6.23333333])
